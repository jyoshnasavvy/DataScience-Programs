# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2    False
# 1         10.34  1.66    Male     No   Sun  Dinner     3    False
# 2         21.01  3.50    Male     No   Sun  Dinner     3    False
# 3         23.68  3.31    Male     No   Sun  Dinner     2    False
# 4         24.59  3.61  Female     No   Sun  Dinner     4    False
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    False
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    False
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    False
# 242       17.82  1.75    Male     No   Sat  Dinner     2    False
# 243       18.78  3.00  Female     No  Thur  Dinner     2    False
#
# [244 rows x 8 columns]

# %% [markdown]
# ### violinplot

# %% [markdown]
#     A Combination of boxplot and kernal density estimation

# %% [markdown]
# ### stripplot

# %% [markdown]
#     A Scotterplot where one variable is categorical. Can be used in conjunction with other plots to show each observation.

# %% [markdown]
# ### swarmplot

# %% [markdown]
#     A categorical scatterplot where the points do not overlap. can be used with other plots to show each obervation.

# %% [markdown]
# ### catplot

# %% [markdown]
#     Combine a categorical plot with a FacetGrid.

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=tips["total_bill"])

# %%
x = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time", data=tips, linewidth=2.8)

# %%
ax = sns.boxplot(x="time", y="tip", data=tips, order=["Dinner", "Lunch"])

# %%
ax = sns.boxplot(x="sex", y="tip", data=tips, order=["Dinner", "Lunch"])

# %%
ax = sns.boxplot(x="size", y="sex", data=tips, order=["Yes", "No"])

# %%
ax = sns.boxplot(x="sex", y="size", data=tips, order=["Yes", "No"])

# %%
tips = sns.load_dataset("tips")
ax = sns.boxplot(data=tips, orient="h")

# %%
tips = sns.load_dataset("tips")
ax = sns.boxplot(data=tips, orient="g")

# %%
tips = sns.load_dataset("tips")
ax = sns.boxplot(data=tips, orient="r")

# %%
tips["weekend"] = tips["day"].isin(["sat","sun"])
ax = sns.boxplot(x="day", y="total_bill", hue="weekend",data=tips, dodge=False)

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
g = sns.catplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, kind="box", height=4, aspect=1);

# %%
g = sns.catplot(x="sex", y="total_bill", hue="day", col="time", data=tips, kind="box", height=4, aspect=1);

# %%
ax = sns.boxplot(x="time", y="total_bill", data=tips)
ax = sns.swarmplot(x="time", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="size", y="total_bill", data=tips)
ax = sns.swarmplot(x="size", y="total_bill", data=tips)
# Out:
# C:\Users\oye  laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.boxplot(x="sex", y="total_bill", data=tips)
ax = sns.swarmplot(x="sex", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="smoker", y="total_bill", data=tips)
ax = sns.swarmplot(x="smoker", y="total_bill", data=tips)
